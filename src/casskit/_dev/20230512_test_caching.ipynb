# %%
import casskit as ck
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import casskit as ck
#
# File ~/Packages/casskit/src/casskit/__init__.py:5
#       2 from pkgutil import extend_path
#       3 import sys
# ----> 5 from . import pp, data
#       7 logger = logging.getLogger(__name__)
#       8 logger.setLevel(logging.INFO)
#
# File ~/Packages/casskit/src/casskit/pp/__init__.py:3
#       1 from pkgutil import extend_path
# ----> 3 from . import copynumber, expression
#       4 from .expression import GTEx
#       6 __all__ = ["copynumber", "expression", "GTEx"]
#
# File ~/Packages/casskit/src/casskit/pp/expression.py:12
#       9 from sklearn.pipeline import Pipeline
#      11 from .generics import VariationThreshold
# ---> 12 from .units import ToCounts
#      13 from ..data.io.annot import get_ensembl
#      14 from ..data.io.descriptors import OneOf
#
# ...
